# %%
# import
import numpy as np
import gym
from gym import spaces
import random

import collections
import copy
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim

# %% [markdown]
# ### Environment

# %%
class MultiAgentActionSpace(list):
    def __init__(self, agents_action_space):
        for x in agents_action_space:
            assert isinstance(x, gym.spaces.space.Space)

        super(MultiAgentActionSpace, self).__init__(agents_action_space)
        self._agents_action_space = agents_action_space

    def sample(self):
        """ samples action for each agent from uniform distribution"""
        return [agent_action_space.sample() for agent_action_space in self._agents_action_space]

# %%
class MultiAgentObservationSpace(list):
    def __init__(self, agents_observation_space):
        for x in agents_observation_space:
            assert isinstance(x, gym.spaces.space.Space)

        super().__init__(agents_observation_space)
        self._agents_observation_space = agents_observation_space

    def sample(self):
        """ samples observations for each agent from uniform distribution"""
        return [agent_observation_space.sample() for agent_observation_space in self._agents_observation_space]

    def contains(self, obs):
        """ contains observation """
        for space, ob in zip(self._agents_observation_space, obs):
            if not space.contains(ob):
                return False
        else:
            return True

# %%
class Grid(gym.Env):
    metadata = {'render.modes': ['console']}
    # action id
    XM = 0 # x minus
    XP = 1 # x plus
    YM = 2 # y minus
    YP = 3 # y plus
    
    def __init__(self, x_size=5, y_size=5, n_agents=2, fov_x=3, fov_y=3):
        super(Grid, self).__init__()
        
        # size of 2D grid
        self.x_size = x_size
        self.y_size = y_size

        # number of agents
        self.n_agents = n_agents
        self.idx_agents = list(range(n_agents)) # [0, 1, 2, ..., n_agents - 1]
        
        # initialize the mapping status
        self.init_grid()

        # initialize the position of the agent
        self.init_agent()
        
        # define action space
        n_actions = 4 # LEFT, RIGHT, TOP, BOTTOM
        self.action_space = MultiAgentActionSpace([spaces.Discrete(n_actions) for _ in range(self.n_agents)])
        
        # define observation space (fielf of view)
        self.fov_x = fov_x # number of cells around the agent
        self.fov_y = fov_y # number of cells around the agent

        self.obs_low = -np.ones(4) * 2 # low -2: out of the grid
        self.obs_high = np.ones(4) # high 1: visited
        self.observation_space = MultiAgentObservationSpace([spaces.Box(self.obs_low, self.obs_high) for _ in range(self.n_agents)])
    
    def init_agent(self, initial_pos=None):
        self.agent_pos = []
        if initial_pos is not None:
            self.agent_pos = initial_pos
            for i in range(self.n_agents):
                self.grid_status[self.agent_pos[i][0], self.agent_pos[i][1]] = 1
        else:
            for i in range(self.n_agents):
                agent_pos_x = random.randrange(0, self.x_size)
                agent_pos_y = random.randrange(0, self.x_size)
                self.agent_pos.append([agent_pos_x, agent_pos_y])
                self.grid_status[self.agent_pos[i][0], self.agent_pos[i][1]] = 1

        # iniqialize the stuck count
        self.stuck_counts = [0] * self.n_agents

    def init_grid(self):
        # initialize the mapping status
        ## -2: out of the grid
        ## -1: obstacle
        ## 0: POI that is not mapped
        ## 1: POI that is mapped
        self.grid_status = np.zeros([self.x_size, self.y_size])
        self.grid_counts = np.zeros([self.x_size, self.y_size])

        ## randomly set obstacles
        # n_obstacle = random.randrange(0, self.x_size * self.x_size * 0.2) # at most 20% of the grid
        n_obstacle = 0
        for i in range(n_obstacle):
            x_obstacle = random.randrange(1, self.x_size - 1)
            y_obstacle = random.randrange(1, self.y_size - 1)
            self.grid_status[x_obstacle, y_obstacle] = - 1
            self.grid_counts[x_obstacle, y_obstacle] = - 1
        
        # number of POI in the environment (0)
        self.n_poi = self.x_size * self.y_size - np.count_nonzero(self.grid_status)
    
    def get_coverage(self):
        mapped_poi = (self.grid_status == 1).sum()
        return mapped_poi / self.n_poi

    def get_agent_obs(self):
        self.agent_obs = []

        # observation for each agent
        for agent in range(self.n_agents):
            # default: out of the grid
            single_obs = -np.ones([self.fov_x, self.fov_y]) * 2
            for i in range(self.fov_x): # 0, 1, 2
                for j in range(self.fov_y): # 0, 1, 2
                    obs_x = self.agent_pos[agent][0] + (i - 1) # -1, 0, 1
                    obs_y = self.agent_pos[agent][1] + (j - 1) # -1, 0, 1
                    if obs_x >= 0 and obs_y >= 0 and obs_x <= self.x_size - 1 and obs_y <= self.y_size - 1:
                        single_obs[i][j] = copy.deepcopy(self.grid_status[obs_x][obs_y])
            single_obs_flat = single_obs.flatten() # convert matrix to list
            # extract the necessary cells
            xm = single_obs_flat[1]
            xp = single_obs_flat[7]
            ym = single_obs_flat[3]
            yp = single_obs_flat[5]
            single_obs_flat = np.array([xm, xp, ym, yp])
            self.agent_obs.append(single_obs_flat)
        return self.agent_obs

    def reset(self, initial_pos=None):
        # initialize the mapping status
        self.init_grid()
        # initialize the position of the agent
        self.init_agent(initial_pos)
        
        # check if the drones at initial positions are surrounded by obstacles
        while True:
            obs = self.get_agent_obs()
            obs_tf = []
            for i in range(self.n_agents):
                agent_obs_tf = obs[i][0] != 0 and obs[i][1] != 0 and obs[i][2] != 0 and obs[i][3] != 0
                obs_tf.append(agent_obs_tf)
            if any(obs_tf):
                self.init_grid()
                self.init_agent()
            else:
                break

        return self.get_agent_obs()
        
    def step(self, action, i): # i: index of the drone
        # original position
        org_x  = copy.deepcopy(self.agent_pos[i][0])
        org_y  = copy.deepcopy(self.agent_pos[i][1])

        # move the agent
        if action == self.XM:
            self.agent_pos[i][0] -= 1
        elif action == self.XP:
            self.agent_pos[i][0] += 1
        elif action == self.YM:
            self.agent_pos[i][1] -= 1
        elif action == self.YP:
            self.agent_pos[i][1] += 1
        else:
            raise ValueError("Received invalid action={} which is not part of the action space".format(action))
        
        # account for the boundaries of the grid (-2: out of the grid)
        if self.agent_pos[i][0] > self.x_size - 1 or self.agent_pos[i][0] < 0 or self.agent_pos[i][1] > self.y_size - 1 or self.agent_pos[i][1] < 0:
            self.agent_pos[i][0] = org_x
            self.agent_pos[i][1] = org_y 
            self.grid_counts[self.agent_pos[i][0], self.agent_pos[i][1]] += 1
            reward = 0
        else:
            # previous status of the cell
            prev_status = self.grid_status[self.agent_pos[i][0], self.agent_pos[i][1]]
            if prev_status == -1: # the new position is on the obstacle
                # go back to the original position
                self.agent_pos[i][0] = org_x
                self.agent_pos[i][1] = org_y
                self.grid_counts[self.agent_pos[i][0], self.agent_pos[i][1]] += 1
                reward = 0
            elif prev_status == 0:
                self.grid_counts[self.agent_pos[i][0], self.agent_pos[i][1]] += 1
                self.grid_status[self.agent_pos[i][0], self.agent_pos[i][1]] = 1
                reward = 10
            elif prev_status == 1:
                self.grid_counts[self.agent_pos[i][0], self.agent_pos[i][1]] += 1
                reward = 0

        # update the stuck count
        if org_x == self.agent_pos[i][0] and org_y == self.agent_pos[i][1]: # stuck
            self.stuck_counts[i] += 1
        else:
            self.stuck_counts[i] = 0

        # are we map all cells?
        mapped_poi = (self.grid_status == 1).sum()
        done = bool(mapped_poi == self.n_poi)
        
        return self.get_agent_obs(), reward, done

    def close(self):
        pass

# %% [markdown]
# ### DQN

# %%
class Net(nn.Module):
    def __init__(self, n_obs, n_mid, n_action):
        super().__init__()
        self.fc1 = nn.Linear(n_obs, n_mid) 
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_action)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
class ReplayBuffer():
    def __init__(self, buffer_limit):
        self.buffer_limit = buffer_limit
        self.buffer = collections.deque(maxlen=self.buffer_limit)
    
    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
    
    def size(self):
        return len(self.buffer)

# %%
class QValues:
    def __init__(self, observation_space, action_space, is_gpu, eps_start=1, eps_end=0.1, r=0.99, gamma=0.9, lr=0.01, buffer_limit=100):
        self.num_agents = len(observation_space)

        self.observation_space = observation_space
        self.observation_values = [-2, -1, 0, 1]
        self.observation_num = len(self.observation_values) # 4
        self.observation_length = observation_space[0].shape[0] # field of view

        self.action_space = action_space
        self.action_values = [0, 1, 2, 3]
        self.action_num = len(self.action_values)

        self.buffer_limit = buffer_limit

        self.is_gpu = is_gpu 

        self.eps = eps_start  # initial epsilon
        self.eps_end = eps_end  # lower bound of epsilon
        self.gamma = gamma  # discount rate
        self.r = r # decrement rate of epsilon
        self.lr = lr # learning rate

        self.net_q = [] # q network
        self.net_target = [] # target network
        self.memory = [] # experience replay
        self.loss_fnc = [] # loss function
        self.optimizer = [] # optimizer
        for i in range(self.num_agents):
            # network
            self.net_q.append(Net(n_obs=self.observation_length, n_mid=16, n_action=self.action_num)) # q network
            self.net_target.append(Net(n_obs=self.observation_length, n_mid=16, n_action=self.action_num)) # target network
            self.net_target[i].load_state_dict(self.net_q[i].state_dict()) # sync parameters
            if self.is_gpu:
                self.net_q[i].cuda()
                self.net_target[i].cuda()

            # memory, loss function, optimizer
            self.memory.append(ReplayBuffer(buffer_limit=self.buffer_limit)) # memory
            self.loss_fnc.append(nn.MSELoss()) # loss function
            self.optimizer.append(optim.Adam(self.net_q[i].parameters(), lr=self.lr)) # optimizer

    def train(self, i, batch_size):
        obs, action, reward, next_obs, done_mask = self.memory[i].sample(batch_size)

        if self.is_gpu:
            obs, action, reward, next_obs, done_mask = obs.cuda(), action.cuda(), reward.cuda(), next_obs.cuda(), done_mask.cuda()

        # current q-value in the online network
        q_out = self.net_q[i](obs) # batch_size x number of actions
        q_a = q_out.gather(1, action) # batch_size x 1 (select the corresponding q-value of each experience)

        # maximum q-value in the target network
        next_q_max = self.net_target[i](next_obs).max(1)[0].unsqueeze(1) # batch_size x 1

        # target
        target = reward + self.gamma * next_q_max * done_mask # batch_size x 1
        
        # difference between the current q-value and the target
        loss = self.loss_fnc[i](q_a, target) # 1 x 1
        self.optimizer[i].zero_grad()
        loss.backward()
        self.optimizer[i].step()
    
    def get_action(self, obs, i, stuck_counts, max_stuck, e_greedy=True, softmax=False):
        obs = torch.from_numpy(obs).float()
        if self.is_gpu:
            obs = obs.cuda()
        
        if stuck_counts[i] >= max_stuck: # random action to avoid stuck
            action = random.choice(self.action_values)
            greedy = False
        elif e_greedy:  # epsilon greedy for training (e_greedy=True)
            if np.random.rand() < self.eps:
                action = random.choice(self.action_values)
                greedy = False
            else:  # make decision with the q network
                q = self.net_q[i].forward(obs) # q values
                action = np.argmax(q.detach().cpu().numpy())
                greedy = True
        elif softmax:  # (e_greedy=False and softmax=True)
            q = self.net_q[i].forward(obs) # q values
            p = self.softmax(q.detach().cpu().numpy())
            action = np.random.choice(np.arange(self.action_num), p=p)
            greedy = False
        else: # all greedy choices for testing performance
            q = self.net_q[i].forward(obs) # q values
            action = np.argmax(q.detach().cpu().numpy())
            greedy = True

        return action, greedy
    
    def softmax(self, a):
        # deal with overflow
        c = np.max(a)
        exp_a = np.exp(a - c)
        sum_exp_a = np.sum(exp_a)
        y = exp_a / sum_exp_a
        return y
    
    def update_target(self):
        for i in range(self.num_agents):
            self.net_target[i].load_state_dict(self.net_q[i].state_dict())
    
    def update_eps(self):
        if self.eps > self.eps_end:
            self.eps *= self.r

# %% [markdown]
# ### Single: Fixed Initial Position

# %%
# ===================================================================================================
# Training: 1 drone
# ===================================================================================================

# records for each episode
time_steps = [] # number of time steps in total
epsilons = [] # epsilon at the end of each episode
greedy = [] # the ratio of greedy choices
coverage = [] # the ratio of visited cells at the end
speed = [] # number of time steps to cover decent amount of cells
sum_q_values = [] # sum of q-values
results_mapping = [] # mapping status
results_count = [] # count status
total_reward = []
total_action_values = []
total_greedy_action_values = []

q_class = []

coverage_threshold = 0.90
max_stuck = 100000

# parameters for training
train_episodes = 200000
max_steps = 10 * 10 * 2
batch_size = 1
interval = 1

# initialize the environment and the q tables
env = Grid(x_size=10, y_size=10, n_agents=1, fov_x=3, fov_y=3)
q = QValues(observation_space=env.observation_space, action_space=env.action_space, is_gpu=False, eps_start=1, eps_end=0, gamma=0.5, r=0.999, lr=0.01, buffer_limit=1)

# training
for episode in range(train_episodes):
    state = env.reset([[0, 0]])
    # state = [arr.astype('int') for arr in state] # convert from float to integer
    eps_tmp = q.eps

    greedy_count = [0] * env.n_agents
    coverage_track = True
    epi_reward = [0] * env.n_agents
    epi_action_value = [0] * env.n_agents
    epi_greedy_action_value = [0] * env.n_agents

    for step in range(max_steps):
        action_order = random.sample(env.idx_agents, env.n_agents) # return a random order of the drone indices
        for agent_i in action_order:
            agent_obs = state[agent_i]
            action, greedy_tf = q.get_action(obs=agent_obs, i=agent_i, stuck_counts=env.stuck_counts, max_stuck=max_stuck, e_greedy=True, softmax=False)
            next_state, reward, done = env.step(action, agent_i)
            # next_state = [arr.astype('int') for arr in next_state] # convert from float to integer
            done_mask = 0.0 if done else 1.0
            agent_next_obs = next_state[agent_i]
            q.memory[agent_i].put((agent_obs, action, reward, agent_next_obs, done_mask))
            epi_reward[agent_i] += reward
            greedy_count[agent_i] += greedy_tf * 1

            if done:
                break
        
            # update the observation
            state = next_state

            # training
            if q.memory[agent_i].size() > 0:
                    q.train(agent_i, batch_size)
            
            # update the target network
            if step % interval == 0:
                q.update_target()

        # check if decent amoung of cells are visited
        current_coverage = env.get_coverage()
        if current_coverage >= coverage_threshold and coverage_track:
            speed.append(step)
            coverage_track = False

        # check if the task is completed
        if done:
            time_steps.append(step)
            break
        elif step == max_steps - 1:
            time_steps.append(step)
            if coverage_track:
                speed.append(np.nan)

    # record
    time_steps.append(step + 1)
    epsilons.append(eps_tmp)
    coverage.append(env.get_coverage())
    greedy.append(list(map(lambda x: x / (step + 1), greedy_count)))
    results_mapping.append(env.grid_status)
    results_count.append(env.grid_counts)
    total_reward.append(epi_reward)

    if episode % 1000 == 0:
        q_class.append(copy.deepcopy(q))

    # update epsilon
    q.update_eps()

    print('//Episode {0}//    Epsilon: {1:.3f},    Steps: {2},    Greedy Choices　(%): {3:.3f},    Coverage (%): {4:.3f},    Steps to Visit {5}% Cells: {6},    Total Reward: {7}'\
          .format(episode+1, q.eps, step+1, np.mean(greedy[episode]), coverage[episode], coverage_threshold * 100, speed[episode], np.mean(total_reward[episode])))
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
# Streaming output truncated to the last 5000 lines.
# //Episode 1723//    Epsilon: 0.178,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.980,    Steps to Visit 90.0% Cells: 148,    Total Reward: 970.0
# //Episode 1724//    Epsilon: 0.178,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.800,    Steps to Visit 90.0% Cells: nan,    Total Reward: 790.0
# //Episode 1725//    Epsilon: 0.178,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.930,    Steps to Visit 90.0% Cells: 151,    Total Reward: 920.0
# //Episode 1726//    Epsilon: 0.178,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1727//    Epsilon: 0.178,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 1728//    Epsilon: 0.177,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.790,    Steps to Visit 90.0% Cells: nan,    Total Reward: 780.0
# //Episode 1729//    Epsilon: 0.177,    Steps: 200,    Greedy Choices　(%): 0.795,    Coverage (%): 0.830,    Steps to Visit 90.0% Cells: nan,    Total Reward: 820.0
# //Episode 1730//    Epsilon: 0.177,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.780,    Steps to Visit 90.0% Cells: nan,    Total Reward: 770.0
# //Episode 1731//    Epsilon: 0.177,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.800,    Steps to Visit 90.0% Cells: nan,    Total Reward: 790.0
# //Episode 1732//    Epsilon: 0.177,    Steps: 200,    Greedy Choices　(%): 0.790,    Coverage (%): 0.840,    Steps to Visit 90.0% Cells: nan,    Total Reward: 830.0
# //Episode 1733//    Epsilon: 0.177,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1734//    Epsilon: 0.176,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.990,    Steps to Visit 90.0% Cells: 131,    Total Reward: 980.0
# //Episode 1735//    Epsilon: 0.176,    Steps: 200,    Greedy Choices　(%): 0.815,    Coverage (%): 0.720,    Steps to Visit 90.0% Cells: nan,    Total Reward: 710.0
# //Episode 1736//    Epsilon: 0.176,    Steps: 200,    Greedy Choices　(%): 0.765,    Coverage (%): 0.800,    Steps to Visit 90.0% Cells: nan,    Total Reward: 790.0
# //Episode 1737//    Epsilon: 0.176,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.930,    Steps to Visit 90.0% Cells: 152,    Total Reward: 920.0
# //Episode 1738//    Epsilon: 0.176,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.950,    Steps to Visit 90.0% Cells: 159,    Total Reward: 940.0
# //Episode 1739//    Epsilon: 0.176,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.980,    Steps to Visit 90.0% Cells: 114,    Total Reward: 970.0
# //Episode 1740//    Epsilon: 0.175,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 177,    Total Reward: 960.0
# //Episode 1741//    Epsilon: 0.175,    Steps: 200,    Greedy Choices　(%): 0.800,    Coverage (%): 0.890,    Steps to Visit 90.0% Cells: nan,    Total Reward: 880.0
# //Episode 1742//    Epsilon: 0.175,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 133,    Total Reward: 950.0
# //Episode 1743//    Epsilon: 0.175,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.830,    Steps to Visit 90.0% Cells: nan,    Total Reward: 820.0
# //Episode 1744//    Epsilon: 0.175,    Steps: 200,    Greedy Choices　(%): 0.815,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 168,    Total Reward: 960.0
# //Episode 1745//    Epsilon: 0.174,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.890,    Steps to Visit 90.0% Cells: nan,    Total Reward: 880.0
# //Episode 1746//    Epsilon: 0.174,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 1747//    Epsilon: 0.174,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1748//    Epsilon: 0.174,    Steps: 200,    Greedy Choices　(%): 0.755,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 134,    Total Reward: 950.0
# //Episode 1749//    Epsilon: 0.174,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1750//    Epsilon: 0.174,    Steps: 200,    Greedy Choices　(%): 0.815,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 181,    Total Reward: 960.0
# //Episode 1751//    Epsilon: 0.173,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.790,    Steps to Visit 90.0% Cells: nan,    Total Reward: 780.0
# //Episode 1752//    Epsilon: 0.173,    Steps: 200,    Greedy Choices　(%): 0.800,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 184,    Total Reward: 890.0
# //Episode 1753//    Epsilon: 0.173,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.780,    Steps to Visit 90.0% Cells: nan,    Total Reward: 770.0
# //Episode 1754//    Epsilon: 0.173,    Steps: 200,    Greedy Choices　(%): 0.775,    Coverage (%): 0.520,    Steps to Visit 90.0% Cells: nan,    Total Reward: 510.0
# //Episode 1755//    Epsilon: 0.173,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.790,    Steps to Visit 90.0% Cells: nan,    Total Reward: 780.0
# //Episode 1756//    Epsilon: 0.173,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.610,    Steps to Visit 90.0% Cells: nan,    Total Reward: 600.0
# //Episode 1757//    Epsilon: 0.172,    Steps: 200,    Greedy Choices　(%): 0.800,    Coverage (%): 0.480,    Steps to Visit 90.0% Cells: nan,    Total Reward: 470.0
# //Episode 1758//    Epsilon: 0.172,    Steps: 200,    Greedy Choices　(%): 0.795,    Coverage (%): 0.640,    Steps to Visit 90.0% Cells: nan,    Total Reward: 630.0
# //Episode 1759//    Epsilon: 0.172,    Steps: 200,    Greedy Choices　(%): 0.785,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1760//    Epsilon: 0.172,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.890,    Steps to Visit 90.0% Cells: nan,    Total Reward: 880.0
# //Episode 1761//    Epsilon: 0.172,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1762//    Epsilon: 0.172,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 109,    Total Reward: 950.0
# //Episode 1763//    Epsilon: 0.171,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.460,    Steps to Visit 90.0% Cells: nan,    Total Reward: 450.0
# //Episode 1764//    Epsilon: 0.171,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 170,    Total Reward: 950.0
# //Episode 1765//    Epsilon: 0.171,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.630,    Steps to Visit 90.0% Cells: nan,    Total Reward: 620.0
# //Episode 1766//    Epsilon: 0.171,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 118,    Total Reward: 950.0
# //Episode 1767//    Epsilon: 0.171,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.640,    Steps to Visit 90.0% Cells: nan,    Total Reward: 630.0
# //Episode 1768//    Epsilon: 0.171,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.740,    Steps to Visit 90.0% Cells: nan,    Total Reward: 730.0
# //Episode 1769//    Epsilon: 0.170,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.730,    Steps to Visit 90.0% Cells: nan,    Total Reward: 720.0
# //Episode 1770//    Epsilon: 0.170,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.840,    Steps to Visit 90.0% Cells: nan,    Total Reward: 830.0
# //Episode 1771//    Epsilon: 0.170,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1772//    Epsilon: 0.170,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 176,    Total Reward: 890.0
# //Episode 1773//    Epsilon: 0.170,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.910,    Steps to Visit 90.0% Cells: 129,    Total Reward: 900.0
# //Episode 1774//    Epsilon: 0.170,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 103,    Total Reward: 960.0
# //Episode 1775//    Epsilon: 0.169,    Steps: 200,    Greedy Choices　(%): 0.815,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1776//    Epsilon: 0.169,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.980,    Steps to Visit 90.0% Cells: 176,    Total Reward: 970.0
# //Episode 1777//    Epsilon: 0.169,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1778//    Epsilon: 0.169,    Steps: 200,    Greedy Choices　(%): 0.790,    Coverage (%): 0.800,    Steps to Visit 90.0% Cells: nan,    Total Reward: 790.0
# //Episode 1779//    Epsilon: 0.169,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.660,    Steps to Visit 90.0% Cells: nan,    Total Reward: 650.0
# //Episode 1780//    Epsilon: 0.168,    Steps: 200,    Greedy Choices　(%): 0.790,    Coverage (%): 0.760,    Steps to Visit 90.0% Cells: nan,    Total Reward: 750.0
# //Episode 1781//    Epsilon: 0.168,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1782//    Epsilon: 0.168,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.450,    Steps to Visit 90.0% Cells: nan,    Total Reward: 440.0
# //Episode 1783//    Epsilon: 0.168,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 1.000,    Steps to Visit 90.0% Cells: 174,    Total Reward: 990.0
# //Episode 1784//    Epsilon: 0.168,    Steps: 200,    Greedy Choices　(%): 0.750,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1785//    Epsilon: 0.168,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.950,    Steps to Visit 90.0% Cells: 103,    Total Reward: 940.0
# //Episode 1786//    Epsilon: 0.167,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 140,    Total Reward: 960.0
# //Episode 1787//    Epsilon: 0.167,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.370,    Steps to Visit 90.0% Cells: nan,    Total Reward: 360.0
# //Episode 1788//    Epsilon: 0.167,    Steps: 200,    Greedy Choices　(%): 0.800,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 165,    Total Reward: 960.0
# //Episode 1789//    Epsilon: 0.167,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1790//    Epsilon: 0.167,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.650,    Steps to Visit 90.0% Cells: nan,    Total Reward: 640.0
# //Episode 1791//    Epsilon: 0.167,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 1792//    Epsilon: 0.166,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.930,    Steps to Visit 90.0% Cells: 192,    Total Reward: 920.0
# //Episode 1793//    Epsilon: 0.166,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.790,    Steps to Visit 90.0% Cells: nan,    Total Reward: 780.0
# //Episode 1794//    Epsilon: 0.166,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.990,    Steps to Visit 90.0% Cells: 110,    Total Reward: 980.0
# //Episode 1795//    Epsilon: 0.166,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.690,    Steps to Visit 90.0% Cells: nan,    Total Reward: 680.0
# //Episode 1796//    Epsilon: 0.166,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.920,    Steps to Visit 90.0% Cells: 162,    Total Reward: 910.0
# //Episode 1797//    Epsilon: 0.166,    Steps: 200,    Greedy Choices　(%): 0.800,    Coverage (%): 0.720,    Steps to Visit 90.0% Cells: nan,    Total Reward: 710.0
# //Episode 1798//    Epsilon: 0.165,    Steps: 200,    Greedy Choices　(%): 0.815,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 151,    Total Reward: 890.0
# //Episode 1799//    Epsilon: 0.165,    Steps: 200,    Greedy Choices　(%): 0.815,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 141,    Total Reward: 960.0
# //Episode 1800//    Epsilon: 0.165,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.850,    Steps to Visit 90.0% Cells: nan,    Total Reward: 840.0
# //Episode 1801//    Epsilon: 0.165,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1802//    Epsilon: 0.165,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.980,    Steps to Visit 90.0% Cells: 106,    Total Reward: 970.0
# //Episode 1803//    Epsilon: 0.165,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.670,    Steps to Visit 90.0% Cells: nan,    Total Reward: 660.0
# //Episode 1804//    Epsilon: 0.164,    Steps: 200,    Greedy Choices　(%): 0.800,    Coverage (%): 0.800,    Steps to Visit 90.0% Cells: nan,    Total Reward: 790.0
# //Episode 1805//    Epsilon: 0.164,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.930,    Steps to Visit 90.0% Cells: 119,    Total Reward: 920.0
# //Episode 1806//    Epsilon: 0.164,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.300,    Steps to Visit 90.0% Cells: nan,    Total Reward: 290.0
# //Episode 1807//    Epsilon: 0.164,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.750,    Steps to Visit 90.0% Cells: nan,    Total Reward: 740.0
# //Episode 1808//    Epsilon: 0.164,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.590,    Steps to Visit 90.0% Cells: nan,    Total Reward: 580.0
# //Episode 1809//    Epsilon: 0.164,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.500,    Steps to Visit 90.0% Cells: nan,    Total Reward: 490.0
# //Episode 1810//    Epsilon: 0.164,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.860,    Steps to Visit 90.0% Cells: nan,    Total Reward: 850.0
# //Episode 1811//    Epsilon: 0.163,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.910,    Steps to Visit 90.0% Cells: 173,    Total Reward: 900.0
# //Episode 1812//    Epsilon: 0.163,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.700,    Steps to Visit 90.0% Cells: nan,    Total Reward: 690.0
# //Episode 1813//    Epsilon: 0.163,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1814//    Epsilon: 0.163,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.650,    Steps to Visit 90.0% Cells: nan,    Total Reward: 640.0
# //Episode 1815//    Epsilon: 0.163,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1816//    Epsilon: 0.163,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.730,    Steps to Visit 90.0% Cells: nan,    Total Reward: 720.0
# //Episode 1817//    Epsilon: 0.162,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.840,    Steps to Visit 90.0% Cells: nan,    Total Reward: 830.0
# //Episode 1818//    Epsilon: 0.162,    Steps: 200,    Greedy Choices　(%): 0.800,    Coverage (%): 0.590,    Steps to Visit 90.0% Cells: nan,    Total Reward: 580.0
# //Episode 1819//    Epsilon: 0.162,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.630,    Steps to Visit 90.0% Cells: nan,    Total Reward: 620.0
# //Episode 1820//    Epsilon: 0.162,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.860,    Steps to Visit 90.0% Cells: nan,    Total Reward: 850.0
# //Episode 1821//    Epsilon: 0.162,    Steps: 200,    Greedy Choices　(%): 0.915,    Coverage (%): 0.670,    Steps to Visit 90.0% Cells: nan,    Total Reward: 660.0
# //Episode 1822//    Epsilon: 0.162,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 131,    Total Reward: 960.0
# //Episode 1823//    Epsilon: 0.161,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.740,    Steps to Visit 90.0% Cells: nan,    Total Reward: 730.0
# //Episode 1824//    Epsilon: 0.161,    Steps: 200,    Greedy Choices　(%): 0.795,    Coverage (%): 0.820,    Steps to Visit 90.0% Cells: nan,    Total Reward: 810.0
# //Episode 1825//    Epsilon: 0.161,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1826//    Epsilon: 0.161,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1827//    Epsilon: 0.161,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 116,    Total Reward: 950.0
# //Episode 1828//    Epsilon: 0.161,    Steps: 200,    Greedy Choices　(%): 0.900,    Coverage (%): 0.930,    Steps to Visit 90.0% Cells: 115,    Total Reward: 920.0
# //Episode 1829//    Epsilon: 0.160,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.890,    Steps to Visit 90.0% Cells: nan,    Total Reward: 880.0
# //Episode 1830//    Epsilon: 0.160,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.820,    Steps to Visit 90.0% Cells: nan,    Total Reward: 810.0
# //Episode 1831//    Epsilon: 0.160,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.910,    Steps to Visit 90.0% Cells: 102,    Total Reward: 900.0
# //Episode 1832//    Epsilon: 0.160,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.910,    Steps to Visit 90.0% Cells: 134,    Total Reward: 900.0
# //Episode 1833//    Epsilon: 0.160,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.500,    Steps to Visit 90.0% Cells: nan,    Total Reward: 490.0
# //Episode 1834//    Epsilon: 0.160,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.720,    Steps to Visit 90.0% Cells: nan,    Total Reward: 710.0
# //Episode 1835//    Epsilon: 0.159,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 1836//    Epsilon: 0.159,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.630,    Steps to Visit 90.0% Cells: nan,    Total Reward: 620.0
# //Episode 1837//    Epsilon: 0.159,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.470,    Steps to Visit 90.0% Cells: nan,    Total Reward: 460.0
# //Episode 1838//    Epsilon: 0.159,    Steps: 200,    Greedy Choices　(%): 0.895,    Coverage (%): 0.480,    Steps to Visit 90.0% Cells: nan,    Total Reward: 470.0
# //Episode 1839//    Epsilon: 0.159,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.450,    Steps to Visit 90.0% Cells: nan,    Total Reward: 440.0
# //Episode 1840//    Epsilon: 0.159,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.740,    Steps to Visit 90.0% Cells: nan,    Total Reward: 730.0
# //Episode 1841//    Epsilon: 0.159,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.780,    Steps to Visit 90.0% Cells: nan,    Total Reward: 770.0
# //Episode 1842//    Epsilon: 0.158,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.620,    Steps to Visit 90.0% Cells: nan,    Total Reward: 610.0
# //Episode 1843//    Epsilon: 0.158,    Steps: 200,    Greedy Choices　(%): 0.885,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1844//    Epsilon: 0.158,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.650,    Steps to Visit 90.0% Cells: nan,    Total Reward: 640.0
# //Episode 1845//    Epsilon: 0.158,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.370,    Steps to Visit 90.0% Cells: nan,    Total Reward: 360.0
# //Episode 1846//    Epsilon: 0.158,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 1847//    Epsilon: 0.158,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1848//    Epsilon: 0.157,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.640,    Steps to Visit 90.0% Cells: nan,    Total Reward: 630.0
# //Episode 1849//    Epsilon: 0.157,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.590,    Steps to Visit 90.0% Cells: nan,    Total Reward: 580.0
# //Episode 1850//    Epsilon: 0.157,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.480,    Steps to Visit 90.0% Cells: nan,    Total Reward: 470.0
# //Episode 1851//    Epsilon: 0.157,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.830,    Steps to Visit 90.0% Cells: nan,    Total Reward: 820.0
# //Episode 1852//    Epsilon: 0.157,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.740,    Steps to Visit 90.0% Cells: nan,    Total Reward: 730.0
# //Episode 1853//    Epsilon: 0.157,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 121,    Total Reward: 960.0
# //Episode 1854//    Epsilon: 0.156,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1855//    Epsilon: 0.156,    Steps: 200,    Greedy Choices　(%): 0.790,    Coverage (%): 0.590,    Steps to Visit 90.0% Cells: nan,    Total Reward: 580.0
# //Episode 1856//    Epsilon: 0.156,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1857//    Epsilon: 0.156,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.910,    Steps to Visit 90.0% Cells: 185,    Total Reward: 900.0
# //Episode 1858//    Epsilon: 0.156,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.740,    Steps to Visit 90.0% Cells: nan,    Total Reward: 730.0
# //Episode 1859//    Epsilon: 0.156,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.520,    Steps to Visit 90.0% Cells: nan,    Total Reward: 510.0
# //Episode 1860//    Epsilon: 0.156,    Steps: 200,    Greedy Choices　(%): 0.795,    Coverage (%): 0.810,    Steps to Visit 90.0% Cells: nan,    Total Reward: 800.0
# //Episode 1861//    Epsilon: 0.155,    Steps: 200,    Greedy Choices　(%): 0.895,    Coverage (%): 0.450,    Steps to Visit 90.0% Cells: nan,    Total Reward: 440.0
# //Episode 1862//    Epsilon: 0.155,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 1863//    Epsilon: 0.155,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.800,    Steps to Visit 90.0% Cells: nan,    Total Reward: 790.0
# //Episode 1864//    Epsilon: 0.155,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.550,    Steps to Visit 90.0% Cells: nan,    Total Reward: 540.0
# //Episode 1865//    Epsilon: 0.155,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.850,    Steps to Visit 90.0% Cells: nan,    Total Reward: 840.0
# //Episode 1866//    Epsilon: 0.155,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.590,    Steps to Visit 90.0% Cells: nan,    Total Reward: 580.0
# //Episode 1867//    Epsilon: 0.154,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.500,    Steps to Visit 90.0% Cells: nan,    Total Reward: 490.0
# //Episode 1868//    Epsilon: 0.154,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.680,    Steps to Visit 90.0% Cells: nan,    Total Reward: 670.0
# //Episode 1869//    Epsilon: 0.154,    Steps: 200,    Greedy Choices　(%): 0.800,    Coverage (%): 0.690,    Steps to Visit 90.0% Cells: nan,    Total Reward: 680.0
# //Episode 1870//    Epsilon: 0.154,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.590,    Steps to Visit 90.0% Cells: nan,    Total Reward: 580.0
# //Episode 1871//    Epsilon: 0.154,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.530,    Steps to Visit 90.0% Cells: nan,    Total Reward: 520.0
# //Episode 1872//    Epsilon: 0.154,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 1873//    Epsilon: 0.154,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 183,    Total Reward: 890.0
# //Episode 1874//    Epsilon: 0.153,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.370,    Steps to Visit 90.0% Cells: nan,    Total Reward: 360.0
# //Episode 1875//    Epsilon: 0.153,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 1876//    Epsilon: 0.153,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1877//    Epsilon: 0.153,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.740,    Steps to Visit 90.0% Cells: nan,    Total Reward: 730.0
# //Episode 1878//    Epsilon: 0.153,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.520,    Steps to Visit 90.0% Cells: nan,    Total Reward: 510.0
# //Episode 1879//    Epsilon: 0.153,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.480,    Steps to Visit 90.0% Cells: nan,    Total Reward: 470.0
# //Episode 1880//    Epsilon: 0.152,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.650,    Steps to Visit 90.0% Cells: nan,    Total Reward: 640.0
# //Episode 1881//    Epsilon: 0.152,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 175,    Total Reward: 890.0
# //Episode 1882//    Epsilon: 0.152,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 1883//    Epsilon: 0.152,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.500,    Steps to Visit 90.0% Cells: nan,    Total Reward: 490.0
# //Episode 1884//    Epsilon: 0.152,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.690,    Steps to Visit 90.0% Cells: nan,    Total Reward: 680.0
# //Episode 1885//    Epsilon: 0.152,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.860,    Steps to Visit 90.0% Cells: nan,    Total Reward: 850.0
# //Episode 1886//    Epsilon: 0.152,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.890,    Steps to Visit 90.0% Cells: nan,    Total Reward: 880.0
# //Episode 1887//    Epsilon: 0.151,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1888//    Epsilon: 0.151,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1889//    Epsilon: 0.151,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 98,    Total Reward: 950.0
# //Episode 1890//    Epsilon: 0.151,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.570,    Steps to Visit 90.0% Cells: nan,    Total Reward: 560.0
# //Episode 1891//    Epsilon: 0.151,    Steps: 200,    Greedy Choices　(%): 0.895,    Coverage (%): 0.540,    Steps to Visit 90.0% Cells: nan,    Total Reward: 530.0
# //Episode 1892//    Epsilon: 0.151,    Steps: 200,    Greedy Choices　(%): 0.785,    Coverage (%): 0.790,    Steps to Visit 90.0% Cells: nan,    Total Reward: 780.0
# //Episode 1893//    Epsilon: 0.150,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.920,    Steps to Visit 90.0% Cells: 189,    Total Reward: 910.0
# //Episode 1894//    Epsilon: 0.150,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1895//    Epsilon: 0.150,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1896//    Epsilon: 0.150,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1897//    Epsilon: 0.150,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 150,    Total Reward: 890.0
# //Episode 1898//    Epsilon: 0.150,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.570,    Steps to Visit 90.0% Cells: nan,    Total Reward: 560.0
# //Episode 1899//    Epsilon: 0.150,    Steps: 200,    Greedy Choices　(%): 0.815,    Coverage (%): 0.760,    Steps to Visit 90.0% Cells: nan,    Total Reward: 750.0
# //Episode 1900//    Epsilon: 0.149,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.930,    Steps to Visit 90.0% Cells: 188,    Total Reward: 920.0
# //Episode 1901//    Epsilon: 0.149,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 114,    Total Reward: 950.0
# //Episode 1902//    Epsilon: 0.149,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 198,    Total Reward: 890.0
# //Episode 1903//    Epsilon: 0.149,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.570,    Steps to Visit 90.0% Cells: nan,    Total Reward: 560.0
# //Episode 1904//    Epsilon: 0.149,    Steps: 200,    Greedy Choices　(%): 0.885,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 189,    Total Reward: 960.0
# //Episode 1905//    Epsilon: 0.149,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 119,    Total Reward: 890.0
# //Episode 1906//    Epsilon: 0.149,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.540,    Steps to Visit 90.0% Cells: nan,    Total Reward: 530.0
# //Episode 1907//    Epsilon: 0.148,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.340,    Steps to Visit 90.0% Cells: nan,    Total Reward: 330.0
# //Episode 1908//    Epsilon: 0.148,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1909//    Epsilon: 0.148,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.780,    Steps to Visit 90.0% Cells: nan,    Total Reward: 770.0
# //Episode 1910//    Epsilon: 0.148,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.630,    Steps to Visit 90.0% Cells: nan,    Total Reward: 620.0
# //Episode 1911//    Epsilon: 0.148,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1912//    Epsilon: 0.148,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.890,    Steps to Visit 90.0% Cells: nan,    Total Reward: 880.0
# //Episode 1913//    Epsilon: 0.147,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.350,    Steps to Visit 90.0% Cells: nan,    Total Reward: 340.0
# //Episode 1914//    Epsilon: 0.147,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.730,    Steps to Visit 90.0% Cells: nan,    Total Reward: 720.0
# //Episode 1915//    Epsilon: 0.147,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.980,    Steps to Visit 90.0% Cells: 155,    Total Reward: 970.0
# //Episode 1916//    Epsilon: 0.147,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.860,    Steps to Visit 90.0% Cells: nan,    Total Reward: 850.0
# //Episode 1917//    Epsilon: 0.147,    Steps: 200,    Greedy Choices　(%): 0.815,    Coverage (%): 0.840,    Steps to Visit 90.0% Cells: nan,    Total Reward: 830.0
# //Episode 1918//    Epsilon: 0.147,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.850,    Steps to Visit 90.0% Cells: nan,    Total Reward: 840.0
# //Episode 1919//    Epsilon: 0.147,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.920,    Steps to Visit 90.0% Cells: 184,    Total Reward: 910.0
# //Episode 1920//    Epsilon: 0.146,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.940,    Steps to Visit 90.0% Cells: 139,    Total Reward: 930.0
# //Episode 1921//    Epsilon: 0.146,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.610,    Steps to Visit 90.0% Cells: nan,    Total Reward: 600.0
# //Episode 1922//    Epsilon: 0.146,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 149,    Total Reward: 950.0
# //Episode 1923//    Epsilon: 0.146,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.850,    Steps to Visit 90.0% Cells: nan,    Total Reward: 840.0
# //Episode 1924//    Epsilon: 0.146,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.850,    Steps to Visit 90.0% Cells: nan,    Total Reward: 840.0
# //Episode 1925//    Epsilon: 0.146,    Steps: 200,    Greedy Choices　(%): 0.805,    Coverage (%): 0.300,    Steps to Visit 90.0% Cells: nan,    Total Reward: 290.0
# //Episode 1926//    Epsilon: 0.146,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.800,    Steps to Visit 90.0% Cells: nan,    Total Reward: 790.0
# //Episode 1927//    Epsilon: 0.145,    Steps: 200,    Greedy Choices　(%): 0.885,    Coverage (%): 0.520,    Steps to Visit 90.0% Cells: nan,    Total Reward: 510.0
# //Episode 1928//    Epsilon: 0.145,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.720,    Steps to Visit 90.0% Cells: nan,    Total Reward: 710.0
# //Episode 1929//    Epsilon: 0.145,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.530,    Steps to Visit 90.0% Cells: nan,    Total Reward: 520.0
# //Episode 1930//    Epsilon: 0.145,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.530,    Steps to Visit 90.0% Cells: nan,    Total Reward: 520.0
# //Episode 1931//    Epsilon: 0.145,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.660,    Steps to Visit 90.0% Cells: nan,    Total Reward: 650.0
# //Episode 1932//    Epsilon: 0.145,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.830,    Steps to Visit 90.0% Cells: nan,    Total Reward: 820.0
# //Episode 1933//    Epsilon: 0.145,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.740,    Steps to Visit 90.0% Cells: nan,    Total Reward: 730.0
# //Episode 1934//    Epsilon: 0.144,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.940,    Steps to Visit 90.0% Cells: 157,    Total Reward: 930.0
# //Episode 1935//    Epsilon: 0.144,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.360,    Steps to Visit 90.0% Cells: nan,    Total Reward: 350.0
# //Episode 1936//    Epsilon: 0.144,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.630,    Steps to Visit 90.0% Cells: nan,    Total Reward: 620.0
# //Episode 1937//    Epsilon: 0.144,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.660,    Steps to Visit 90.0% Cells: nan,    Total Reward: 650.0
# //Episode 1938//    Epsilon: 0.144,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.760,    Steps to Visit 90.0% Cells: nan,    Total Reward: 750.0
# //Episode 1939//    Epsilon: 0.144,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.920,    Steps to Visit 90.0% Cells: 169,    Total Reward: 910.0
# //Episode 1940//    Epsilon: 0.144,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.580,    Steps to Visit 90.0% Cells: nan,    Total Reward: 570.0
# //Episode 1941//    Epsilon: 0.143,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.950,    Steps to Visit 90.0% Cells: 164,    Total Reward: 940.0
# //Episode 1942//    Epsilon: 0.143,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.410,    Steps to Visit 90.0% Cells: nan,    Total Reward: 400.0
# //Episode 1943//    Epsilon: 0.143,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.660,    Steps to Visit 90.0% Cells: nan,    Total Reward: 650.0
# //Episode 1944//    Epsilon: 0.143,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1945//    Epsilon: 0.143,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.850,    Steps to Visit 90.0% Cells: nan,    Total Reward: 840.0
# //Episode 1946//    Epsilon: 0.143,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.930,    Steps to Visit 90.0% Cells: 166,    Total Reward: 920.0
# //Episode 1947//    Epsilon: 0.143,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.600,    Steps to Visit 90.0% Cells: nan,    Total Reward: 590.0
# //Episode 1948//    Epsilon: 0.142,    Steps: 200,    Greedy Choices　(%): 0.885,    Coverage (%): 0.380,    Steps to Visit 90.0% Cells: nan,    Total Reward: 370.0
# //Episode 1949//    Epsilon: 0.142,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.850,    Steps to Visit 90.0% Cells: nan,    Total Reward: 840.0
# //Episode 1950//    Epsilon: 0.142,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.730,    Steps to Visit 90.0% Cells: nan,    Total Reward: 720.0
# //Episode 1951//    Epsilon: 0.142,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.760,    Steps to Visit 90.0% Cells: nan,    Total Reward: 750.0
# //Episode 1952//    Epsilon: 0.142,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.590,    Steps to Visit 90.0% Cells: nan,    Total Reward: 580.0
# //Episode 1953//    Epsilon: 0.142,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.590,    Steps to Visit 90.0% Cells: nan,    Total Reward: 580.0
# //Episode 1954//    Epsilon: 0.142,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.940,    Steps to Visit 90.0% Cells: 165,    Total Reward: 930.0
# //Episode 1955//    Epsilon: 0.141,    Steps: 200,    Greedy Choices　(%): 0.825,    Coverage (%): 0.550,    Steps to Visit 90.0% Cells: nan,    Total Reward: 540.0
# //Episode 1956//    Epsilon: 0.141,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.950,    Steps to Visit 90.0% Cells: 150,    Total Reward: 940.0
# //Episode 1957//    Epsilon: 0.141,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.660,    Steps to Visit 90.0% Cells: nan,    Total Reward: 650.0
# //Episode 1958//    Epsilon: 0.141,    Steps: 200,    Greedy Choices　(%): 0.810,    Coverage (%): 0.820,    Steps to Visit 90.0% Cells: nan,    Total Reward: 810.0
# //Episode 1959//    Epsilon: 0.141,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 129,    Total Reward: 890.0
# //Episode 1960//    Epsilon: 0.141,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.940,    Steps to Visit 90.0% Cells: 119,    Total Reward: 930.0
# //Episode 1961//    Epsilon: 0.141,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 199,    Total Reward: 890.0
# //Episode 1962//    Epsilon: 0.140,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.480,    Steps to Visit 90.0% Cells: nan,    Total Reward: 470.0
# //Episode 1963//    Epsilon: 0.140,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.750,    Steps to Visit 90.0% Cells: nan,    Total Reward: 740.0
# //Episode 1964//    Epsilon: 0.140,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.910,    Steps to Visit 90.0% Cells: 103,    Total Reward: 900.0
# //Episode 1965//    Epsilon: 0.140,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.770,    Steps to Visit 90.0% Cells: nan,    Total Reward: 760.0
# //Episode 1966//    Epsilon: 0.140,    Steps: 200,    Greedy Choices　(%): 0.820,    Coverage (%): 0.940,    Steps to Visit 90.0% Cells: 174,    Total Reward: 930.0
# //Episode 1967//    Epsilon: 0.140,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.780,    Steps to Visit 90.0% Cells: nan,    Total Reward: 770.0
# //Episode 1968//    Epsilon: 0.140,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.950,    Steps to Visit 90.0% Cells: 98,    Total Reward: 940.0
# //Episode 1969//    Epsilon: 0.139,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.810,    Steps to Visit 90.0% Cells: nan,    Total Reward: 800.0
# //Episode 1970//    Epsilon: 0.139,    Steps: 200,    Greedy Choices　(%): 0.830,    Coverage (%): 0.890,    Steps to Visit 90.0% Cells: nan,    Total Reward: 880.0
# //Episode 1971//    Epsilon: 0.139,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.560,    Steps to Visit 90.0% Cells: nan,    Total Reward: 550.0
# //Episode 1972//    Epsilon: 0.139,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.910,    Steps to Visit 90.0% Cells: 134,    Total Reward: 900.0
# //Episode 1973//    Epsilon: 0.139,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.780,    Steps to Visit 90.0% Cells: nan,    Total Reward: 770.0
# //Episode 1974//    Epsilon: 0.139,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 182,    Total Reward: 890.0
# //Episode 1975//    Epsilon: 0.139,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.990,    Steps to Visit 90.0% Cells: 106,    Total Reward: 980.0
# //Episode 1976//    Epsilon: 0.138,    Steps: 200,    Greedy Choices　(%): 0.880,    Coverage (%): 0.820,    Steps to Visit 90.0% Cells: nan,    Total Reward: 810.0
# //Episode 1977//    Epsilon: 0.138,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.840,    Steps to Visit 90.0% Cells: nan,    Total Reward: 830.0
# //Episode 1978//    Epsilon: 0.138,    Steps: 200,    Greedy Choices　(%): 0.905,    Coverage (%): 0.970,    Steps to Visit 90.0% Cells: 145,    Total Reward: 960.0
# //Episode 1979//    Epsilon: 0.138,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.730,    Steps to Visit 90.0% Cells: nan,    Total Reward: 720.0
# //Episode 1980//    Epsilon: 0.138,    Steps: 137,    Greedy Choices　(%): 0.905,    Coverage (%): 1.000,    Steps to Visit 90.0% Cells: 123,    Total Reward: 990.0
# //Episode 1981//    Epsilon: 0.138,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.840,    Steps to Visit 90.0% Cells: nan,    Total Reward: 830.0
# //Episode 1982//    Epsilon: 0.138,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.830,    Steps to Visit 90.0% Cells: nan,    Total Reward: 820.0
# //Episode 1983//    Epsilon: 0.138,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.870,    Steps to Visit 90.0% Cells: nan,    Total Reward: 860.0
# //Episode 1984//    Epsilon: 0.137,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.780,    Steps to Visit 90.0% Cells: nan,    Total Reward: 770.0
# //Episode 1985//    Epsilon: 0.137,    Steps: 200,    Greedy Choices　(%): 0.910,    Coverage (%): 0.600,    Steps to Visit 90.0% Cells: nan,    Total Reward: 590.0
# //Episode 1986//    Epsilon: 0.137,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.990,    Steps to Visit 90.0% Cells: 175,    Total Reward: 980.0
# //Episode 1987//    Epsilon: 0.137,    Steps: 200,    Greedy Choices　(%): 0.845,    Coverage (%): 0.860,    Steps to Visit 90.0% Cells: nan,    Total Reward: 850.0
# //Episode 1988//    Epsilon: 0.137,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.810,    Steps to Visit 90.0% Cells: nan,    Total Reward: 800.0
# //Episode 1989//    Epsilon: 0.137,    Steps: 200,    Greedy Choices　(%): 0.890,    Coverage (%): 0.800,    Steps to Visit 90.0% Cells: nan,    Total Reward: 790.0
# //Episode 1990//    Epsilon: 0.137,    Steps: 200,    Greedy Choices　(%): 0.885,    Coverage (%): 0.950,    Steps to Visit 90.0% Cells: 107,    Total Reward: 940.0
# //Episode 1991//    Epsilon: 0.136,    Steps: 200,    Greedy Choices　(%): 0.860,    Coverage (%): 0.990,    Steps to Visit 90.0% Cells: 105,    Total Reward: 980.0
# //Episode 1992//    Epsilon: 0.136,    Steps: 200,    Greedy Choices　(%): 0.885,    Coverage (%): 0.790,    Steps to Visit 90.0% Cells: nan,    Total Reward: 780.0
# //Episode 1993//    Epsilon: 0.136,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.840,    Steps to Visit 90.0% Cells: nan,    Total Reward: 830.0
# //Episode 1994//    Epsilon: 0.136,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.900,    Steps to Visit 90.0% Cells: 155,    Total Reward: 890.0
# //Episode 1995//    Epsilon: 0.136,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 1996//    Epsilon: 0.136,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.990,    Steps to Visit 90.0% Cells: 113,    Total Reward: 980.0
# //Episode 1997//    Epsilon: 0.136,    Steps: 200,    Greedy Choices　(%): 0.870,    Coverage (%): 0.920,    Steps to Visit 90.0% Cells: 171,    Total Reward: 910.0
# //Episode 1998//    Epsilon: 0.135,    Steps: 200,    Greedy Choices　(%): 0.900,    Coverage (%): 0.640,    Steps to Visit 90.0% Cells: nan,    Total Reward: 630.0
# //Episode 1999//    Epsilon: 0.135,    Steps: 200,    Greedy Choices　(%): 0.900,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 122,    Total Reward: 950.0
# //Episode 2000//    Epsilon: 0.135,    Steps: 200,    Greedy Choices　(%): 0.905,    Coverage (%): 0.880,    Steps to Visit 90.0% Cells: nan,    Total Reward: 870.0
# //Episode 2001//    Epsilon: 0.135,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.960,    Steps to Visit 90.0% Cells: 133,    Total Reward: 950.0
# //Episode 2002//    Epsilon: 0.135,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.790,    Steps to Visit 90.0% Cells: nan,    Total Reward: 780.0
# //Episode 2003//    Epsilon: 0.135,    Steps: 200,    Greedy Choices　(%): 0.855,    Coverage (%): 0.890,    Steps to Visit 90.0% Cells: nan,    Total Reward: 880.0
# //Episode 2004//    Epsilon: 0.135,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.830,    Steps to Visit 90.0% Cells: nan,    Total Reward: 820.0
# //Episode 2005//    Epsilon: 0.135,    Steps: 200,    Greedy Choices　(%): 0.875,    Coverage (%): 0.700,    Steps to Visit 90.0% Cells: nan,    Total Reward: 690.0
# //Episode 2006//    Epsilon: 0.134,    Steps: 200,    Greedy Choices　(%): 0.865,    Coverage (%): 0.760,    Steps to Visit 90.0% Cells: nan,    Total Reward: 750.0
# //Episode 2007//    Epsilon: 0.134,    Steps: 200,    Greedy Choices　(%): 0.840,    Coverage (%): 0.710,    Steps to Visit 90.0% Cells: nan,    Total Reward: 700.0
# //Episode 2008//    Epsilon: 0.134,    Steps: 200,    Greedy Choices　(%): 0.885,    Coverage (%): 0.540,    Steps to Visit 90.0% Cells: nan,    Total Reward: 530.0
# //Episode 2009//    Epsilon: 0.134,    Steps: 200,    Greedy Choices　(%): 0.835,    Coverage (%): 0.830,    Steps to Visit 90.0% Cells: nan,    Total Reward: 820.0
# //Episode 2010//    Epsilon: 0.134,    Steps: 200,    Greedy Choices　(%): 0.850,    Coverage (%): 0.830,    Steps to Visit 90.0% Cells: nan,    Total Reward: 820.0
# //Episode 2011//    Epsilon: 0.134,    Steps: 200,    Greedy Choices　(%): 0.885,    Coverage (%): 0.700,    Steps to Visit 90.0% Cells: nan,    Total Reward: 690.0
# ...
# //Episode 6638//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6639//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.990,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6640//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6641//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6642//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6643//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6644//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6645//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6646//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6647//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6648//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.990,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6649//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.270,    Steps to Visit 90.0% Cells: nan,    Total Reward: 260.0
# //Episode 6650//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.370,    Steps to Visit 90.0% Cells: nan,    Total Reward: 360.0
# //Episode 6651//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6652//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6653//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6654//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6655//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6656//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6657//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.990,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6658//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6659//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6660//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6661//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6662//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6663//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6664//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6665//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6666//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6667//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6668//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6669//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6670//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6671//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6672//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6673//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6674//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6675//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6676//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6677//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6678//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6679//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6680//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6681//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6682//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6683//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6684//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6685//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6686//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6687//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6688//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6689//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6690//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6691//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6692//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6693//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6694//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6695//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6696//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6697//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6698//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6699//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6700//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6701//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6702//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6703//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6704//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6705//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6706//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6707//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6708//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6709//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6710//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6711//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6712//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6713//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.985,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6714//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.220,    Steps to Visit 90.0% Cells: nan,    Total Reward: 210.0
# //Episode 6715//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6716//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6717//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6718//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6719//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6720//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.190,    Steps to Visit 90.0% Cells: nan,    Total Reward: 180.0
# //Episode 6721//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 0.995,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# //Episode 6722//    Epsilon: 0.001,    Steps: 200,    Greedy Choices　(%): 1.000,    Coverage (%): 0.280,    Steps to Visit 90.0% Cells: nan,    Total Reward: 270.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-41ba88b9f252> in <module>()
#      64             # training
#      65             if q.memory[agent_i].size() > 0:
# ---> 66                     q.train(agent_i, batch_size)
#      67
#      68             # update the target network
#
# <ipython-input-8-942ee4d106e3> in train(self, i, batch_size)
#      61         self.optimizer[i].zero_grad()
#      62         loss.backward()
# ---> 63         self.optimizer[i].step()
#      64
#      65     def get_action(self, obs, i, stuck_counts, max_stuck, e_greedy=True, softmax=False):
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     142                    lr=group['lr'],
#     143                    weight_decay=group['weight_decay'],
# --> 144                    eps=group['eps'])
#     145         return loss
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      77         step = state_steps[i]
#      78
# ---> 79         bias_correction1 = 1 - beta1 ** step
#      80         bias_correction2 = 1 - beta2 ** step
#      81
#
# KeyboardInterrupt:

# %%
import joblib

# %%
joblib.dump(q_class, "q_class_multi_random.txt", compress=3)
# Out:
# ['q_class_multi_random.txt']

# %%
df = pd.DataFrame(q_class[40-1].q_tables[1])
df.to_csv('qtable.csv')

# %%
q_last = copy.deepcopy(q)

# %%
state = env.reset([[0, 0], [9, 9]])
state = [arr.astype('int') for arr in state] # convert from float to integer
q_last.eps = 0
trajectory_1 = [[0, 0]]
trajectory_2 = [[9, 9]]
reward_1 = []
reward_2 = []
action_1 = []
action_2 = []

for step in range(max_steps):
    action_order = [0, 1]
    for agent_i in action_order:
        action, greedy_tf, action_value = q_last.get_action(observations=state, agent_i=agent_i, stuck_counts=env.stuck_counts, max_stuck=max_stuck, e_greedy=True, softmax=False)
        next_state, reward, done = env.step(action, agent_i)
        next_state = [arr.astype('int') for arr in next_state] # convert from float to integer
        if agent_i == 0:
            trajectory_1.append(copy.deepcopy(env.agent_pos[0]))
            reward_1.append(reward)
            action_1.append(action)
        else:
            trajectory_2.append(copy.deepcopy(env.agent_pos[1]))
            reward_2.append(reward)
            action_2.append(action)

        if done:
            break
    
        # update the observation
        state = next_state

    # check if the task is completed
    if done:
        break

print(step)
# Out:
# 90

# %%
print(len(trajectory_1), len(reward_1), len(action_1))
# Out:
# 92 91 91

# %%
reward_1.append(np.nan)
action_1.append(np.nan)

# %%
print(len(trajectory_2), len(reward_2), len(action_2))
# Out:
# 91 90 90

# %%
reward_2.append(np.nan)
action_2.append(np.nan)

# %%
env.get_coverage()
# Out:
# 1.0

# %%
df = pd.DataFrame({'trajectory': trajectory_1, 'reward': reward_1, 'action': action_1})
df.to_csv('trajectory.csv')

# %%
df = pd.DataFrame({'trajectory': trajectory_2, 'reward': reward_2, 'action': action_2})
df.to_csv('trajectory.csv')

# %%
# ===================================================================================================
# Test
# ===================================================================================================

# records for each episode
time_steps = [] # number of time steps in total
epsilons = [] # epsilon at the end of each episode
greedy = [] # the ratio of greedy choices
coverage = [] # the ratio of visited cells at the end
speed = [] # number of time steps to cover decent amount of cells
sum_q_values = [] # sum of q-values
results_mapping = [] # mapping status
results_count = [] # count status
total_reward = []
total_action_values = []
total_greedy_action_values = []

q_class = []

coverage_threshold = 0.95
max_stuck = 100000

# parameters for training
test_episodes = 100
size = 50
max_steps = size * size * 2

# initialize the environment and the q tables
env = Grid(x_size=size, y_size=size,  n_agents=2, fov_x=3, fov_y=3)

# training
for episode in range(test_episodes):
    state = env.reset()
    state = [arr.astype('int') for arr in state] # convert from float to integer

    greedy_count = [0] * env.n_agents
    coverage_track = True
    epi_reward = [0] * env.n_agents
    epi_action_value = [0] * env.n_agents
    epi_greedy_action_value = [0] * env.n_agents

    for step in range(max_steps):
        action_order = [0, 1]
        for agent_i in action_order:
            action, greedy_tf, action_value = q_last.get_action(observations=state, agent_i=agent_i, stuck_counts=env.stuck_counts, max_stuck=max_stuck, e_greedy=True, softmax=False)
            next_state, reward, done = env.step(action, agent_i)
            next_state = [arr.astype('int') for arr in next_state] # convert from float to integer

            epi_reward[agent_i] += reward
            greedy_count[agent_i] += greedy_tf * 1
            epi_action_value[agent_i] += action_value
            epi_greedy_action_value[agent_i] += action_value * greedy_tf

            if done:
                break
        
            # update the observation
            state = next_state

        # check if decent amoung of cells are visited
        current_coverage = env.get_coverage()
        if current_coverage >= coverage_threshold and coverage_track:
            speed.append(step)
            coverage_track = False

        # check if the task is completed
        if done:
            time_steps.append(step)
            break
        elif step == max_steps - 1:
            time_steps.append(step)
            if coverage_track:
                speed.append(np.nan)

    # record
    time_steps.append(step + 1)
    epsilons.append(eps_tmp)
    coverage.append(env.get_coverage())
    greedy.append(list(map(lambda x: x / (step + 1), greedy_count)))
    sum_q_values.append([q.q_tables[0].sum()])
    results_mapping.append(env.grid_status)
    results_count.append(env.grid_counts)
    total_reward.append(epi_reward)
    total_action_values.append(epi_action_value)
    total_greedy_action_values.append(epi_greedy_action_value)

    print('//Episode {0}//    Epsilon: {1:.3f},    Steps: {2},    Greedy Choices　(%): {3:.3f},    Coverage (%): {4:.3f},    Steps to Visit {5}% Cells: {6},    Sum of Q-Values: {7:.1f},    Total Reward: {8}'\
          .format(episode+1, eps_tmp, step+1, np.mean(greedy[episode]), coverage[episode], coverage_threshold * 100, speed[episode], sum_q_values[episode][0], np.mean(total_reward[episode])))
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# //Episode 1//    Epsilon: 0.000,    Steps: 1284,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1215,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 2//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 1571,    Sum of Q-Values: 2953.1,    Total Reward: 12470.0
# //Episode 3//    Epsilon: 0.000,    Steps: 1330,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1213,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 4//    Epsilon: 0.000,    Steps: 1360,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1252,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 5//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 1491,    Sum of Q-Values: 2953.1,    Total Reward: 12450.0
# //Episode 6//    Epsilon: 0.000,    Steps: 1283,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1207,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 7//    Epsilon: 0.000,    Steps: 1321,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1190,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 8//    Epsilon: 0.000,    Steps: 1305,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1189,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 9//    Epsilon: 0.000,    Steps: 1595,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1212,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 10//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.994,    Steps to Visit 95.0% Cells: 1451,    Sum of Q-Values: 2953.1,    Total Reward: 12415.0
# //Episode 11//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.993,    Steps to Visit 95.0% Cells: 1628,    Sum of Q-Values: 2953.1,    Total Reward: 12405.0
# //Episode 12//    Epsilon: 0.000,    Steps: 1806,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1680,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 13//    Epsilon: 0.000,    Steps: 1373,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1231,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 14//    Epsilon: 0.000,    Steps: 1312,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1248,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 15//    Epsilon: 0.000,    Steps: 1387,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1280,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 16//    Epsilon: 0.000,    Steps: 1288,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1225,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 17//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 1844,    Sum of Q-Values: 2953.1,    Total Reward: 12455.0
# //Episode 18//    Epsilon: 0.000,    Steps: 1357,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1276,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 19//    Epsilon: 0.000,    Steps: 1322,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1248,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 20//    Epsilon: 0.000,    Steps: 1364,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1279,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 21//    Epsilon: 0.000,    Steps: 1318,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1254,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 22//    Epsilon: 0.000,    Steps: 1364,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1291,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 23//    Epsilon: 0.000,    Steps: 1534,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1408,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 24//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.992,    Steps to Visit 95.0% Cells: 1349,    Sum of Q-Values: 2953.1,    Total Reward: 12390.0
# //Episode 25//    Epsilon: 0.000,    Steps: 1890,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1764,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 26//    Epsilon: 0.000,    Steps: 1380,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1270,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 27//    Epsilon: 0.000,    Steps: 1309,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1215,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 28//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.988,    Steps to Visit 95.0% Cells: 1226,    Sum of Q-Values: 2953.1,    Total Reward: 12345.0
# //Episode 29//    Epsilon: 0.000,    Steps: 1340,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1225,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 30//    Epsilon: 0.000,    Steps: 1273,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1209,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 31//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.996,    Steps to Visit 95.0% Cells: 1246,    Sum of Q-Values: 2953.1,    Total Reward: 12435.0
# //Episode 32//    Epsilon: 0.000,    Steps: 1307,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1232,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 33//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 1248,    Sum of Q-Values: 2953.1,    Total Reward: 12450.0
# //Episode 34//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 1262,    Sum of Q-Values: 2953.1,    Total Reward: 12430.0
# //Episode 35//    Epsilon: 0.000,    Steps: 1788,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1647,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 36//    Epsilon: 0.000,    Steps: 1305,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1205,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 37//    Epsilon: 0.000,    Steps: 1321,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1212,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 38//    Epsilon: 0.000,    Steps: 1323,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1233,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 39//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.992,    Steps to Visit 95.0% Cells: 1238,    Sum of Q-Values: 2953.1,    Total Reward: 12395.0
# //Episode 40//    Epsilon: 0.000,    Steps: 1378,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1207,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 41//    Epsilon: 0.000,    Steps: 1367,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1225,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 42//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.990,    Steps to Visit 95.0% Cells: 1398,    Sum of Q-Values: 2953.1,    Total Reward: 12370.0
# //Episode 43//    Epsilon: 0.000,    Steps: 1316,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1234,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 44//    Epsilon: 0.000,    Steps: 1736,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1610,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 45//    Epsilon: 0.000,    Steps: 1333,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1270,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 46//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.992,    Steps to Visit 95.0% Cells: 1417,    Sum of Q-Values: 2953.1,    Total Reward: 12395.0
# //Episode 47//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.996,    Steps to Visit 95.0% Cells: 1206,    Sum of Q-Values: 2953.1,    Total Reward: 12445.0
# //Episode 48//    Epsilon: 0.000,    Steps: 1994,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1868,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 49//    Epsilon: 0.000,    Steps: 1859,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1733,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 50//    Epsilon: 0.000,    Steps: 1303,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1200,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 51//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.992,    Steps to Visit 95.0% Cells: 1811,    Sum of Q-Values: 2953.1,    Total Reward: 12390.0
# //Episode 52//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.983,    Steps to Visit 95.0% Cells: 1917,    Sum of Q-Values: 2953.1,    Total Reward: 12275.0
# //Episode 53//    Epsilon: 0.000,    Steps: 1875,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1749,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 54//    Epsilon: 0.000,    Steps: 1634,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1508,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 55//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 1830,    Sum of Q-Values: 2953.1,    Total Reward: 12480.0
# //Episode 56//    Epsilon: 0.000,    Steps: 1306,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1225,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 57//    Epsilon: 0.000,    Steps: 1284,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1221,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 58//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.993,    Steps to Visit 95.0% Cells: 2218,    Sum of Q-Values: 2953.1,    Total Reward: 12405.0
# //Episode 59//    Epsilon: 0.000,    Steps: 1294,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1226,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 60//    Epsilon: 0.000,    Steps: 1375,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1233,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 61//    Epsilon: 0.000,    Steps: 1892,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1766,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 62//    Epsilon: 0.000,    Steps: 1311,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1200,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 63//    Epsilon: 0.000,    Steps: 1953,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1827,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 64//    Epsilon: 0.000,    Steps: 1300,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1236,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 65//    Epsilon: 0.000,    Steps: 1315,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1223,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 66//    Epsilon: 0.000,    Steps: 1279,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1188,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 67//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.994,    Steps to Visit 95.0% Cells: 2110,    Sum of Q-Values: 2953.1,    Total Reward: 12410.0
# //Episode 68//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.991,    Steps to Visit 95.0% Cells: 1261,    Sum of Q-Values: 2953.1,    Total Reward: 12380.0
# //Episode 69//    Epsilon: 0.000,    Steps: 1321,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1224,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 70//    Epsilon: 0.000,    Steps: 1311,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1236,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 71//    Epsilon: 0.000,    Steps: 1308,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1244,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 72//    Epsilon: 0.000,    Steps: 1339,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1257,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 73//    Epsilon: 0.000,    Steps: 1311,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1223,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 74//    Epsilon: 0.000,    Steps: 1371,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1285,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 75//    Epsilon: 0.000,    Steps: 1289,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1226,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 76//    Epsilon: 0.000,    Steps: 1809,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1683,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 77//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 1501,    Sum of Q-Values: 2953.1,    Total Reward: 12450.0
# //Episode 78//    Epsilon: 0.000,    Steps: 1343,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1265,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 79//    Epsilon: 0.000,    Steps: 1339,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1233,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 80//    Epsilon: 0.000,    Steps: 1389,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1223,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 81//    Epsilon: 0.000,    Steps: 1313,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1216,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 82//    Epsilon: 0.000,    Steps: 2134,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 2008,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 83//    Epsilon: 0.000,    Steps: 1749,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1582,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 84//    Epsilon: 0.000,    Steps: 1307,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1198,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 85//    Epsilon: 0.000,    Steps: 1298,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1232,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 86//    Epsilon: 0.000,    Steps: 2207,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 2081,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 87//    Epsilon: 0.000,    Steps: 1768,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1642,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 88//    Epsilon: 0.000,    Steps: 1333,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1270,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 89//    Epsilon: 0.000,    Steps: 1342,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1270,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 90//    Epsilon: 0.000,    Steps: 1411,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1284,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 91//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1665,    Sum of Q-Values: 2953.1,    Total Reward: 12485.0
# //Episode 92//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.996,    Steps to Visit 95.0% Cells: 1255,    Sum of Q-Values: 2953.1,    Total Reward: 12445.0
# //Episode 93//    Epsilon: 0.000,    Steps: 1499,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1201,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 94//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 1217,    Sum of Q-Values: 2953.1,    Total Reward: 12425.0
# //Episode 95//    Epsilon: 0.000,    Steps: 1365,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1223,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 96//    Epsilon: 0.000,    Steps: 1358,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1251,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 97//    Epsilon: 0.000,    Steps: 1363,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1259,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 98//    Epsilon: 0.000,    Steps: 5000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.988,    Steps to Visit 95.0% Cells: 1211,    Sum of Q-Values: 2953.1,    Total Reward: 12340.0
# //Episode 99//    Epsilon: 0.000,    Steps: 1383,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1291,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0
# //Episode 100//    Epsilon: 0.000,    Steps: 2024,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 1898,    Sum of Q-Values: 2953.1,    Total Reward: 12490.0

# %%
np.mean(coverage)
# Out:
# 0.998468

# %%
np.mean(speed)
# Out:
# 1386.35

# %%
# ===================================================================================================
# Test
# ===================================================================================================

# records for each episode
time_steps = [] # number of time steps in total
epsilons = [] # epsilon at the end of each episode
greedy = [] # the ratio of greedy choices
coverage = [] # the ratio of visited cells at the end
speed = [] # number of time steps to cover decent amount of cells
sum_q_values = [] # sum of q-values
results_mapping = [] # mapping status
results_count = [] # count status
total_reward = []
total_action_values = []
total_greedy_action_values = []

q_class = []

coverage_threshold = 0.95
max_stuck = 100000

# parameters for training
test_episodes = 100
size = 100
max_steps = size * size * 2

# initialize the environment and the q tables
env = Grid(x_size=size, y_size=size,  n_agents=2, fov_x=3, fov_y=3)

# training
for episode in range(test_episodes):
    state = env.reset()
    state = [arr.astype('int') for arr in state] # convert from float to integer

    greedy_count = [0] * env.n_agents
    coverage_track = True
    epi_reward = [0] * env.n_agents
    epi_action_value = [0] * env.n_agents
    epi_greedy_action_value = [0] * env.n_agents

    for step in range(max_steps):
        action_order = [0, 1]
        for agent_i in action_order:
            action, greedy_tf, action_value = q_last.get_action(observations=state, agent_i=agent_i, stuck_counts=env.stuck_counts, max_stuck=max_stuck, e_greedy=True, softmax=False)
            next_state, reward, done = env.step(action, agent_i)
            next_state = [arr.astype('int') for arr in next_state] # convert from float to integer

            epi_reward[agent_i] += reward
            greedy_count[agent_i] += greedy_tf * 1
            epi_action_value[agent_i] += action_value
            epi_greedy_action_value[agent_i] += action_value * greedy_tf

            if done:
                break
        
            # update the observation
            state = next_state

        # check if decent amoung of cells are visited
        current_coverage = env.get_coverage()
        if current_coverage >= coverage_threshold and coverage_track:
            speed.append(step)
            coverage_track = False

        # check if the task is completed
        if done:
            time_steps.append(step)
            break
        elif step == max_steps - 1:
            time_steps.append(step)
            if coverage_track:
                speed.append(np.nan)

    # record
    time_steps.append(step + 1)
    epsilons.append(eps_tmp)
    coverage.append(env.get_coverage())
    greedy.append(list(map(lambda x: x / (step + 1), greedy_count)))
    sum_q_values.append([q.q_tables[0].sum()])
    results_mapping.append(env.grid_status)
    results_count.append(env.grid_counts)
    total_reward.append(epi_reward)
    total_action_values.append(epi_action_value)
    total_greedy_action_values.append(epi_greedy_action_value)

    print('//Episode {0}//    Epsilon: {1:.3f},    Steps: {2},    Greedy Choices　(%): {3:.3f},    Coverage (%): {4:.3f},    Steps to Visit {5}% Cells: {6},    Sum of Q-Values: {7:.1f},    Total Reward: {8}'\
          .format(episode+1, eps_tmp, step+1, np.mean(greedy[episode]), coverage[episode], coverage_threshold * 100, speed[episode], sum_q_values[episode][0], np.mean(total_reward[episode])))
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# //Episode 1//    Epsilon: 0.000,    Steps: 5203,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4931,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 2//    Epsilon: 0.000,    Steps: 5212,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4880,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 3//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 5784,    Sum of Q-Values: 2953.1,    Total Reward: 49955.0
# //Episode 4//    Epsilon: 0.000,    Steps: 5165,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4867,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 5//    Epsilon: 0.000,    Steps: 5155,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4900,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 6//    Epsilon: 0.000,    Steps: 5173,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4860,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 7//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.994,    Steps to Visit 95.0% Cells: 4785,    Sum of Q-Values: 2953.1,    Total Reward: 49665.0
# //Episode 8//    Epsilon: 0.000,    Steps: 5903,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4793,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 9//    Epsilon: 0.000,    Steps: 5145,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4805,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 10//    Epsilon: 0.000,    Steps: 5115,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4794,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 11//    Epsilon: 0.000,    Steps: 5271,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4869,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 12//    Epsilon: 0.000,    Steps: 5229,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4944,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 13//    Epsilon: 0.000,    Steps: 5624,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4804,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 14//    Epsilon: 0.000,    Steps: 5210,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4787,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 15//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 4842,    Sum of Q-Values: 2953.1,    Total Reward: 49825.0
# //Episode 16//    Epsilon: 0.000,    Steps: 5268,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4968,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 17//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 4806,    Sum of Q-Values: 2953.1,    Total Reward: 49715.0
# //Episode 18//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 7864,    Sum of Q-Values: 2953.1,    Total Reward: 49930.0
# //Episode 19//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 6707,    Sum of Q-Values: 2953.1,    Total Reward: 49855.0
# //Episode 20//    Epsilon: 0.000,    Steps: 5259,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4855,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 21//    Epsilon: 0.000,    Steps: 5189,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4922,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 22//    Epsilon: 0.000,    Steps: 5268,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4978,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 23//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 5407,    Sum of Q-Values: 2953.1,    Total Reward: 49845.0
# //Episode 24//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 6948,    Sum of Q-Values: 2953.1,    Total Reward: 49970.0
# //Episode 25//    Epsilon: 0.000,    Steps: 7702,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 7141,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 26//    Epsilon: 0.000,    Steps: 5203,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4806,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 27//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.996,    Steps to Visit 95.0% Cells: 4812,    Sum of Q-Values: 2953.1,    Total Reward: 49795.0
# //Episode 28//    Epsilon: 0.000,    Steps: 5657,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4810,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 29//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 5353,    Sum of Q-Values: 2953.1,    Total Reward: 49740.0
# //Episode 30//    Epsilon: 0.000,    Steps: 5015,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4764,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 31//    Epsilon: 0.000,    Steps: 5247,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4752,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 32//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.992,    Steps to Visit 95.0% Cells: 5565,    Sum of Q-Values: 2953.1,    Total Reward: 49565.0
# //Episode 33//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 4817,    Sum of Q-Values: 2953.1,    Total Reward: 49955.0
# //Episode 34//    Epsilon: 0.000,    Steps: 5110,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4859,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 35//    Epsilon: 0.000,    Steps: 5180,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4866,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 36//    Epsilon: 0.000,    Steps: 5267,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4855,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 37//    Epsilon: 0.000,    Steps: 5819,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 5241,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 38//    Epsilon: 0.000,    Steps: 5192,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4834,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 39//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 4806,    Sum of Q-Values: 2953.1,    Total Reward: 49945.0
# //Episode 40//    Epsilon: 0.000,    Steps: 8396,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 7820,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 41//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.996,    Steps to Visit 95.0% Cells: 4795,    Sum of Q-Values: 2953.1,    Total Reward: 49785.0
# //Episode 42//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 4788,    Sum of Q-Values: 2953.1,    Total Reward: 49845.0
# //Episode 43//    Epsilon: 0.000,    Steps: 8214,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 7713,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 44//    Epsilon: 0.000,    Steps: 5239,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4938,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 45//    Epsilon: 0.000,    Steps: 5019,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4768,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 46//    Epsilon: 0.000,    Steps: 6261,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 5693,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 47//    Epsilon: 0.000,    Steps: 5151,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4780,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 48//    Epsilon: 0.000,    Steps: 5237,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4935,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 49//    Epsilon: 0.000,    Steps: 5139,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4759,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 50//    Epsilon: 0.000,    Steps: 5136,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4883,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 51//    Epsilon: 0.000,    Steps: 5245,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4942,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 52//    Epsilon: 0.000,    Steps: 5224,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4944,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 53//    Epsilon: 0.000,    Steps: 5237,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4947,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 54//    Epsilon: 0.000,    Steps: 5155,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4823,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 55//    Epsilon: 0.000,    Steps: 5221,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4917,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 56//    Epsilon: 0.000,    Steps: 5153,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4829,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 57//    Epsilon: 0.000,    Steps: 5088,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4837,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 58//    Epsilon: 0.000,    Steps: 7982,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 7481,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 59//    Epsilon: 0.000,    Steps: 5223,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4808,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 60//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 5866,    Sum of Q-Values: 2953.1,    Total Reward: 49895.0
# //Episode 61//    Epsilon: 0.000,    Steps: 5063,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4796,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 62//    Epsilon: 0.000,    Steps: 5180,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4925,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 63//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 4982,    Sum of Q-Values: 2953.1,    Total Reward: 49920.0
# //Episode 64//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.996,    Steps to Visit 95.0% Cells: 4885,    Sum of Q-Values: 2953.1,    Total Reward: 49775.0
# //Episode 65//    Epsilon: 0.000,    Steps: 5163,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4748,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 66//    Epsilon: 0.000,    Steps: 5245,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4808,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 67//    Epsilon: 0.000,    Steps: 5193,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4867,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 68//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 6818,    Sum of Q-Values: 2953.1,    Total Reward: 49905.0
# //Episode 69//    Epsilon: 0.000,    Steps: 8803,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 8302,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 70//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 5189,    Sum of Q-Values: 2953.1,    Total Reward: 49815.0
# //Episode 71//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 5348,    Sum of Q-Values: 2953.1,    Total Reward: 49920.0
# //Episode 72//    Epsilon: 0.000,    Steps: 5250,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4777,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 73//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 5949,    Sum of Q-Values: 2953.1,    Total Reward: 49840.0
# //Episode 74//    Epsilon: 0.000,    Steps: 5115,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4778,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 75//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 8095,    Sum of Q-Values: 2953.1,    Total Reward: 49905.0
# //Episode 76//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 4759,    Sum of Q-Values: 2953.1,    Total Reward: 49885.0
# //Episode 77//    Epsilon: 0.000,    Steps: 5283,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4862,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 78//    Epsilon: 0.000,    Steps: 5093,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4798,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 79//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4813,    Sum of Q-Values: 2953.1,    Total Reward: 49975.0
# //Episode 80//    Epsilon: 0.000,    Steps: 5283,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4809,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 81//    Epsilon: 0.000,    Steps: 5147,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4845,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 82//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 5655,    Sum of Q-Values: 2953.1,    Total Reward: 49880.0
# //Episode 83//    Epsilon: 0.000,    Steps: 5107,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4840,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 84//    Epsilon: 0.000,    Steps: 6463,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 5962,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 85//    Epsilon: 0.000,    Steps: 5265,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4857,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 86//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 4805,    Sum of Q-Values: 2953.1,    Total Reward: 49870.0
# //Episode 87//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.996,    Steps to Visit 95.0% Cells: 4845,    Sum of Q-Values: 2953.1,    Total Reward: 49790.0
# //Episode 88//    Epsilon: 0.000,    Steps: 5137,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4795,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 89//    Epsilon: 0.000,    Steps: 7904,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 7403,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 90//    Epsilon: 0.000,    Steps: 5070,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4808,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 91//    Epsilon: 0.000,    Steps: 5496,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4794,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 92//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 5688,    Sum of Q-Values: 2953.1,    Total Reward: 49960.0
# //Episode 93//    Epsilon: 0.000,    Steps: 5199,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4907,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 94//    Epsilon: 0.000,    Steps: 6739,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 6238,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 95//    Epsilon: 0.000,    Steps: 5245,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4898,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 96//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 6288,    Sum of Q-Values: 2953.1,    Total Reward: 49910.0
# //Episode 97//    Epsilon: 0.000,    Steps: 20000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 5188,    Sum of Q-Values: 2953.1,    Total Reward: 49755.0
# //Episode 98//    Epsilon: 0.000,    Steps: 5187,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4771,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 99//    Epsilon: 0.000,    Steps: 5075,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4824,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0
# //Episode 100//    Epsilon: 0.000,    Steps: 5120,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 4869,    Sum of Q-Values: 2953.1,    Total Reward: 49990.0

# %%
np.mean(coverage)
# Out:
# 0.99914

# %%
np.mean(speed)
# Out:
# 5262.35

# %%
# ===================================================================================================
# Test
# ===================================================================================================

# records for each episode
time_steps = [] # number of time steps in total
epsilons = [] # epsilon at the end of each episode
greedy = [] # the ratio of greedy choices
coverage = [] # the ratio of visited cells at the end
speed = [] # number of time steps to cover decent amount of cells
sum_q_values = [] # sum of q-values
results_mapping = [] # mapping status
results_count = [] # count status
total_reward = []
total_action_values = []
total_greedy_action_values = []

q_class = []

coverage_threshold = 0.95
max_stuck = 100000

# parameters for training
test_episodes = 100
size = 150
max_steps = size * size * 2

# initialize the environment and the q tables
env = Grid(x_size=size, y_size=size,  n_agents=2, fov_x=3, fov_y=3)

# training
for episode in range(test_episodes):
    state = env.reset()
    state = [arr.astype('int') for arr in state] # convert from float to integer

    greedy_count = [0] * env.n_agents
    coverage_track = True
    epi_reward = [0] * env.n_agents
    epi_action_value = [0] * env.n_agents
    epi_greedy_action_value = [0] * env.n_agents

    for step in range(max_steps):
        action_order = [0, 1]
        for agent_i in action_order:
            action, greedy_tf, action_value = q_last.get_action(observations=state, agent_i=agent_i, stuck_counts=env.stuck_counts, max_stuck=max_stuck, e_greedy=True, softmax=False)
            next_state, reward, done = env.step(action, agent_i)
            next_state = [arr.astype('int') for arr in next_state] # convert from float to integer

            epi_reward[agent_i] += reward
            greedy_count[agent_i] += greedy_tf * 1
            epi_action_value[agent_i] += action_value
            epi_greedy_action_value[agent_i] += action_value * greedy_tf

            if done:
                break
        
            # update the observation
            state = next_state

        # check if decent amoung of cells are visited
        current_coverage = env.get_coverage()
        if current_coverage >= coverage_threshold and coverage_track:
            speed.append(step)
            coverage_track = False

        # check if the task is completed
        if done:
            time_steps.append(step)
            break
        elif step == max_steps - 1:
            time_steps.append(step)
            if coverage_track:
                speed.append(np.nan)

    # record
    time_steps.append(step + 1)
    epsilons.append(eps_tmp)
    coverage.append(env.get_coverage())
    greedy.append(list(map(lambda x: x / (step + 1), greedy_count)))
    sum_q_values.append([q.q_tables[0].sum()])
    results_mapping.append(env.grid_status)
    results_count.append(env.grid_counts)
    total_reward.append(epi_reward)
    total_action_values.append(epi_action_value)
    total_greedy_action_values.append(epi_greedy_action_value)

    print('//Episode {0}//    Epsilon: {1:.3f},    Steps: {2},    Greedy Choices　(%): {3:.3f},    Coverage (%): {4:.3f},    Steps to Visit {5}% Cells: {6},    Sum of Q-Values: {7:.1f},    Total Reward: {8}'\
          .format(episode+1, eps_tmp, step+1, np.mean(greedy[episode]), coverage[episode], coverage_threshold * 100, speed[episode], sum_q_values[episode][0], np.mean(total_reward[episode])))
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# //Episode 1//    Epsilon: 0.000,    Steps: 14682,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 13556,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 2//    Epsilon: 0.000,    Steps: 11671,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 11040,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 3//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10959,    Sum of Q-Values: 2953.1,    Total Reward: 112465.0
# //Episode 4//    Epsilon: 0.000,    Steps: 11473,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10853,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 5//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 10960,    Sum of Q-Values: 2953.1,    Total Reward: 112320.0
# //Episode 6//    Epsilon: 0.000,    Steps: 16111,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 14985,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 7//    Epsilon: 0.000,    Steps: 11475,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10834,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 8//    Epsilon: 0.000,    Steps: 15008,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 13882,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 9//    Epsilon: 0.000,    Steps: 12522,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10784,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 10//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 12770,    Sum of Q-Values: 2953.1,    Total Reward: 112235.0
# //Episode 11//    Epsilon: 0.000,    Steps: 11555,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10954,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 12//    Epsilon: 0.000,    Steps: 11441,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10796,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 13//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 11937,    Sum of Q-Values: 2953.1,    Total Reward: 112415.0
# //Episode 14//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 11838,    Sum of Q-Values: 2953.1,    Total Reward: 112325.0
# //Episode 15//    Epsilon: 0.000,    Steps: 18273,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 17007,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 16//    Epsilon: 0.000,    Steps: 17374,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 16248,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 17//    Epsilon: 0.000,    Steps: 11445,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10823,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 18//    Epsilon: 0.000,    Steps: 17510,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 16239,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 19//    Epsilon: 0.000,    Steps: 11795,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10906,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 20//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 13489,    Sum of Q-Values: 2953.1,    Total Reward: 112115.0
# //Episode 21//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 11943,    Sum of Q-Values: 2953.1,    Total Reward: 112295.0
# //Episode 22//    Epsilon: 0.000,    Steps: 11533,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10829,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 23//    Epsilon: 0.000,    Steps: 20706,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 19580,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 24//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 14453,    Sum of Q-Values: 2953.1,    Total Reward: 112195.0
# //Episode 25//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 16241,    Sum of Q-Values: 2953.1,    Total Reward: 111950.0
# //Episode 26//    Epsilon: 0.000,    Steps: 11473,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10789,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 27//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 12372,    Sum of Q-Values: 2953.1,    Total Reward: 112210.0
# //Episode 28//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 14420,    Sum of Q-Values: 2953.1,    Total Reward: 111960.0
# //Episode 29//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 13963,    Sum of Q-Values: 2953.1,    Total Reward: 112225.0
# //Episode 30//    Epsilon: 0.000,    Steps: 11473,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10855,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 31//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 16130,    Sum of Q-Values: 2953.1,    Total Reward: 112205.0
# //Episode 32//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10749,    Sum of Q-Values: 2953.1,    Total Reward: 112445.0
# //Episode 33//    Epsilon: 0.000,    Steps: 11541,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10946,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 34//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 13605,    Sum of Q-Values: 2953.1,    Total Reward: 112230.0
# //Episode 35//    Epsilon: 0.000,    Steps: 11473,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10845,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 36//    Epsilon: 0.000,    Steps: 11604,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10971,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 37//    Epsilon: 0.000,    Steps: 11591,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10997,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 38//    Epsilon: 0.000,    Steps: 11476,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10910,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 39//    Epsilon: 0.000,    Steps: 13972,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 12846,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 40//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 11033,    Sum of Q-Values: 2953.1,    Total Reward: 111875.0
# //Episode 41//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 15482,    Sum of Q-Values: 2953.1,    Total Reward: 112425.0
# //Episode 42//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 11879,    Sum of Q-Values: 2953.1,    Total Reward: 112455.0
# //Episode 43//    Epsilon: 0.000,    Steps: 11726,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10784,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 44//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 11851,    Sum of Q-Values: 2953.1,    Total Reward: 112310.0
# //Episode 45//    Epsilon: 0.000,    Steps: 11550,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10876,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 46//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 13667,    Sum of Q-Values: 2953.1,    Total Reward: 112420.0
# //Episode 47//    Epsilon: 0.000,    Steps: 11551,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10837,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 48//    Epsilon: 0.000,    Steps: 11305,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10729,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 49//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.997,    Steps to Visit 95.0% Cells: 10876,    Sum of Q-Values: 2953.1,    Total Reward: 112150.0
# //Episode 50//    Epsilon: 0.000,    Steps: 11887,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10761,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 51//    Epsilon: 0.000,    Steps: 19644,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 18380,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 52//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 11005,    Sum of Q-Values: 2953.1,    Total Reward: 112385.0
# //Episode 53//    Epsilon: 0.000,    Steps: 14460,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 13334,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 54//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10904,    Sum of Q-Values: 2953.1,    Total Reward: 112435.0
# //Episode 55//    Epsilon: 0.000,    Steps: 11605,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10698,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 56//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 14551,    Sum of Q-Values: 2953.1,    Total Reward: 112375.0
# //Episode 57//    Epsilon: 0.000,    Steps: 16003,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 14761,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 58//    Epsilon: 0.000,    Steps: 11586,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10952,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 59//    Epsilon: 0.000,    Steps: 11469,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10901,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 60//    Epsilon: 0.000,    Steps: 14407,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 13159,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 61//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 16804,    Sum of Q-Values: 2953.1,    Total Reward: 112250.0
# //Episode 62//    Epsilon: 0.000,    Steps: 11421,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10848,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 63//    Epsilon: 0.000,    Steps: 11687,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10921,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 64//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 14024,    Sum of Q-Values: 2953.1,    Total Reward: 112420.0
# //Episode 65//    Epsilon: 0.000,    Steps: 11645,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10951,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 66//    Epsilon: 0.000,    Steps: 12058,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10758,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 67//    Epsilon: 0.000,    Steps: 11396,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10832,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 68//    Epsilon: 0.000,    Steps: 11400,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10836,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 69//    Epsilon: 0.000,    Steps: 11473,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10808,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 70//    Epsilon: 0.000,    Steps: 12625,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 11499,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 71//    Epsilon: 0.000,    Steps: 16133,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 14896,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 72//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.999,    Steps to Visit 95.0% Cells: 18704,    Sum of Q-Values: 2953.1,    Total Reward: 112380.0
# //Episode 73//    Epsilon: 0.000,    Steps: 11564,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10946,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 74//    Epsilon: 0.000,    Steps: 11433,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10696,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 75//    Epsilon: 0.000,    Steps: 11462,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10898,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 76//    Epsilon: 0.000,    Steps: 11576,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10960,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 77//    Epsilon: 0.000,    Steps: 16160,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 15034,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 78//    Epsilon: 0.000,    Steps: 11401,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10777,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 79//    Epsilon: 0.000,    Steps: 11725,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10877,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 80//    Epsilon: 0.000,    Steps: 11441,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10734,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 81//    Epsilon: 0.000,    Steps: 11535,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10762,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 82//    Epsilon: 0.000,    Steps: 11499,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10895,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 83//    Epsilon: 0.000,    Steps: 11495,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10920,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 84//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 13661,    Sum of Q-Values: 2953.1,    Total Reward: 112225.0
# //Episode 85//    Epsilon: 0.000,    Steps: 11604,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10971,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 86//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 15384,    Sum of Q-Values: 2953.1,    Total Reward: 112280.0
# //Episode 87//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.998,    Steps to Visit 95.0% Cells: 16859,    Sum of Q-Values: 2953.1,    Total Reward: 112240.0
# //Episode 88//    Epsilon: 0.000,    Steps: 12675,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 11452,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 89//    Epsilon: 0.000,    Steps: 11290,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10727,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 90//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.994,    Steps to Visit 95.0% Cells: 15407,    Sum of Q-Values: 2953.1,    Total Reward: 111865.0
# //Episode 91//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.995,    Steps to Visit 95.0% Cells: 10736,    Sum of Q-Values: 2953.1,    Total Reward: 111950.0
# //Episode 92//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10872,    Sum of Q-Values: 2953.1,    Total Reward: 112475.0
# //Episode 93//    Epsilon: 0.000,    Steps: 11665,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10853,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 94//    Epsilon: 0.000,    Steps: 13649,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 12523,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 95//    Epsilon: 0.000,    Steps: 12534,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 11279,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 96//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 0.996,    Steps to Visit 95.0% Cells: 15457,    Sum of Q-Values: 2953.1,    Total Reward: 111985.0
# //Episode 97//    Epsilon: 0.000,    Steps: 45000,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 14417,    Sum of Q-Values: 2953.1,    Total Reward: 112450.0
# //Episode 98//    Epsilon: 0.000,    Steps: 11575,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10870,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 99//    Epsilon: 0.000,    Steps: 12580,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 11442,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0
# //Episode 100//    Epsilon: 0.000,    Steps: 11473,    Greedy Choices　(%): 1.000,    Coverage (%): 1.000,    Steps to Visit 95.0% Cells: 10864,    Sum of Q-Values: 2953.1,    Total Reward: 112490.0

# %%
np.mean(coverage)
# Out:
# 0.9992702222222222

# %%
np.mean(speed)
# Out:
# 12408.78
